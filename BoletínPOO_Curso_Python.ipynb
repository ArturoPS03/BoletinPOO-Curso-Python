# %% [markdown]
# <a href="https://colab.research.google.com/github/ArturoPS03/BoletinPOO-Curso-Python/blob/main/Bolet%C3%ADnPOO_Curso_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ejercicio3001.py

# %%
class Galleta:
    def _init_(self, nombre):
        self.nombre = nombre

    def _hornear_(self):
        print("Esta galleta con chispas de chocolate ha sido horneada en forma de estrella")
        print("buen provecho")

        Galleta.hornear()

# %% [markdown]
# # ejercicio3002.py

# %%
class Libro:
    def __init__(self, titulo, autor, precio):
        self.titulo = titulo
        self.autor = autor
        self.precio = precio

    def Mostrar_informaciones(self):
        print(f"Título: {self.titulo}")
        print(f"Autor: {self.autor}")
        print(f"Precio: ${self.precio:.2f}")

# %% [markdown]
# # ejercicio3003.py

# %%
class Nota:
    def _init_(self,nota,nombreEstudiante):
        self.nota=nota,
        self.nombreEstudiante=nombreEstudiante

    def ha_pasado(self):
        if self.nota>=75:
            print("El estudiante ha pasado")
        else:
            print("El estudiante no ha pasado")

# %% [markdown]
# # ejercicio3004.py

# %%
class Circulo:
    def _init_(self,x,y,r):
        self.x = x
        self.y = y
        self.r = r

    def area(self):
        return 3.1415 * (self.r ** 2)

    def perimetro(self):
        return 2 * 3.1415 * self.r

    def mostrar_propiedades(self):
        print(f"Centro: ({self.x}, {self.y})")
        print(f"Radio: {self.r}")
        print(f"Área: {self.area()}")
        print(f"Perímetro: {self.perimetro()}")

# %% [markdown]
# # ejercicio3005.py

# %%
class Operacion:
    def _init_(self,x,y):
        self.x = x
        self.y = y

    def suma(self):
        return self.x + self.y

    def multiplicacion(self):
        return self.x * self.y

    def division(self):
        if self.y != 0:
            return self.x / self.y
        else:
            print("Error, división por 0")

# %% [markdown]
# # ejercicio3006.py

# %%
class Persona:
    def _init_(self,nombre,edad,genero):
        self.nombre=nombre
        self.edad=edad
        self.genero=genero

    def presentrarse(self):
        return f"Hola, me llamo {self.nombre}, tengo {self.edad} años y soy {self.genero}."

    def esAdulto(self):
        if self.edad >= 18:
            return True
        else:
            return False

# %% [markdown]
# # ejercicio3007.py

# %%
# from ejercicio3006 import Persona -->
class Persona:
    def _init_(self,nombre,edad,genero):
        self.nombre=nombre
        self.edad=edad
        self.genero=genero

    def presentrarse(self):
        return f"Hola, me llamo {self.nombre}, tengo {self.edad} años y soy {self.genero}."

    def esAdulto(self):
        if self.edad >= 18:
            return True
        else:
            return False

#-----------------------------------------------------------
class Estudiante(Persona):
    def __init__(self, nombre, edad, genero, nivel):
        super().__init__(nombre, edad, genero)
        self.nivel = nivel

    def inscripcion(self,estudiantes_inscritos):
        estudiantes_inscritos.append(self)

# %% [markdown]
# # ejercicio3008.py

# %%
class dado:

    def __init__(self, marca=0):
        self.marca = marca

    def lanzar_dado(self):
        import random
        self.marca = random.randint(1, 6)
        return self.marca

    def mostrar_puntos(self):
        print(self.marca)

# %% [markdown]
# # ejercicio3009.py

# %%
class Vehiculo:
    def __init__(self, marca, velocidad_inicial=0):
        self.marca = marca
        self.velocidad = velocidad_inicial

    def acelerar(self, v):
        self.velocidad += v

    def desacelerar(self, v):
        self.velocidad -= v

    def mostrar_velocidad(self):
        return self.velocidad

class Coche(Vehiculo):
    def __init__(self, marca, velocidad_inicial=0,bocina="tuuut"):
        super().__init__(marca, velocidad_inicial)
        self.bocina = bocina

    def Tocar_claxon(self):
        print(self.bocina)

# %% [markdown]
# # ejercicio3010.py

# %%
class Empleado:
    def _init_(self,nombre,funcion,salario,horasTrabajadas=0):
        self.nombre=nombre
        self.funcion=funcion
        self.salario=salario
        self.horasTrabajadas=horasTrabajadas

    def trabajar(self,num_horas):
        self.horasTrabajadas += num_horas
        return self.horasTrabajadas

    def info_sueldo(self):
        return f"{self.salario}"

    def dar_aumento(self,cantidad):
        self.salario += cantidad

    def info_funcion(self):
        return f"{self.funcion}"

# %% [markdown]
# # ejercicio3011.py

# %%
class Calculo_numerico:
    def _init_(self, numero):
        self.numero = numero

    def calculo_factorial(self):
        if self.numero == 0 or self.numero == 1:
            return 1
        else:
            factorial = 1
            for i in range(2, self.numero + 1):
                factorial *= i
            return factorial

    def lista_divisores(self):
        divisores = []
        for i in range(1, self.numero + 1):
            if self.numero % i == 0:
                divisores.append(i)
        return divisores

    def esPrimo(self):
        if self.numero <= 1:
            return False
        for i in range(2, int(self.numero**0.5) + 1):
            if self.numero % i == 0:
                return False
        return True

    def esPar(self):
        return self.numero % 2 == 0

# %% [markdown]
# # ejercicio3012.py

# %%
class Video:
    def _init_(self,titulo,duracion,categoria):
        self.titulo = titulo
        self.duracion = duracion
        self.categoria = categoria

    def mirar_video(self):
        print("Observando el video...")

    def detener_video(self):
        print("Video detenido")

class Audio:
    def _init_(self,titulo,artista):
        self.titulo = titulo
        self.artista = artista

    def escuchar_audio(self):
        print("Escuchando audio")

    def detener_audio(self):
        print("Audio detenido")

class Media(Video,Audio):
    def _init(self,titulo,categoria,duracion,artista):
        super()._init_(titulo,duracion,categoria,artista)
